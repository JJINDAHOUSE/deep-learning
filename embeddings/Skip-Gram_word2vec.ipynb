# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count / total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold / freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size + 1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start: idx] + words[idx + 1: stop + 1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev = 0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6580 0.2563 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6120 0.2503 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5040 0.2495 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6021 0.2674 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5007 0.2661 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5570 0.2494 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5487 0.2646 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5490 0.2655 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4794 0.2672 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4085 0.2599 sec/batch
# Nearest to were: kanembu, views, franck, adema, fouling, confirm, hillel, stripped,
# Nearest to on: dispenses, paisiello, upland, crowell, inventors, plus, mq, overlooked,
# Nearest to not: masked, resisting, prophet, gillian, electrostatic, struma, subjugated, tetanus,
# Nearest to up: dalek, dire, sparrowhawk, agility, regents, custody, syringes, dakuten,
# Nearest to the: plasmodium, fireflies, suomen, urge, moneypenny, contestant, legalization, extensionality,
# Nearest to world: babes, decorate, older, superheroic, pennants, crewman, lumpy, statius,
# Nearest to which: saaremaa, jigoro, machismo, dominates, persistent, gnawing, normally, danza,
# Nearest to eight: mitten, vacuous, crosby, salaino, internacia, fictitious, diamonds, outgoing,
# Nearest to report: wherever, mithras, outings, linn, showmanship, polk, lr, pinning,
# Nearest to grand: reconquista, roca, indicator, lyons, seimas, semiautomatic, multidimensional, cricetulus,
# Nearest to ocean: agrarianism, protease, sicilies, herrn, preslar, risked, tgv, lifeless,
# Nearest to centre: herbst, zealots, manasses, anegada, wobble, mathew, grandparent, hani,
# Nearest to san: galliard, eidos, quotient, asf, crawl, hz, iannis, nd,
# Nearest to something: stadium, committed, sizeof, bystanders, ili, authorization, cosmology, blok,
# Nearest to construction: iggy, pack, palazzo, unitar, invictus, automobile, shortcuts, litre,
# Nearest to active: anger, historiae, ihre, gulden, worshipping, ophelia, malinche, poppy,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4923 0.2528 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3898 0.2507 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2851 0.2611 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2537 0.2794 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1816 0.2610 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1614 0.2720 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0744 0.2607 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0529 0.2696 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9701 0.2679 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9569 0.2680 sec/batch
# Nearest to were: views, confirm, kanembu, fouling, franck, stripped, don, called,
# Nearest to on: plus, upland, overlooked, asian, dispenses, paisiello, incompletely, inventors,
# Nearest to not: masked, prophet, resisting, community, freedom, deprogrammer, electrostatic, rising,
# Nearest to up: custody, dalek, dire, sparrowhawk, core, recognition, agility, transverse,
# Nearest to the: plasmodium, suomen, succession, automobile, fireflies, benefit, stores, legacies,
# Nearest to world: older, babes, decorate, practical, related, organisms, pennants, psychology,
# Nearest to which: whole, dominates, falling, persistent, saaremaa, normally, military, jigoro,
# Nearest to eight: mitten, vacuous, margin, salaino, crosby, outgoing, diamonds, commonwealth,
# Nearest to report: wherever, surgeon, linn, outings, transistors, polk, grasped, showmanship,
# Nearest to grand: indicator, reconquista, lyons, roca, seimas, laser, multidimensional, prize,
# Nearest to ocean: greater, protease, agrarianism, down, sicilies, duke, herrn, lifeless,
# Nearest to centre: herbst, zealots, monro, pretending, convert, side, proportional, caricom,
# Nearest to san: quotient, nd, galliard, eidos, iannis, asf, unrecognized, crawl,
# Nearest to something: stadium, committed, regarding, authorization, amenities, field, residents, this,
# Nearest to construction: pack, litre, iggy, c, automobile, invictus, shortcuts, grants,
# Nearest to active: anger, historiae, decreased, democratic, continuously, throughout, confluence, worshipping,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9304 0.2737 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8826 0.2671 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8792 0.2581 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8503 0.2633 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7914 0.2651 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8215 0.2662 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8001 0.2633 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8070 0.2725 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7753 0.2578 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8078 0.2669 sec/batch
# Nearest to were: views, stripped, kanembu, confirm, franck, clerk, fouling, travelers,
# Nearest to on: plus, upland, dispenses, overlooked, inventors, paisiello, asian, wars,
# Nearest to not: masked, captivity, resisting, absolutely, outlawed, statism, prophet, electrostatic,
# Nearest to up: custody, dire, dalek, sparrowhawk, agility, ninety, isolated, invoked,
# Nearest to the: succession, suomen, legacies, automobile, halting, somebody, divinity, fireflies,
# Nearest to world: babes, decorate, older, theme, practical, related, organisms, incomes,
# Nearest to which: falling, dominates, remove, persistent, appoint, conclusions, avid, stroke,
# Nearest to eight: outgoing, crosby, mitten, vacuous, diamonds, margin, bohlen, salaino,
# Nearest to report: wherever, transistors, linn, surgeon, surinam, grasped, outings, polk,
# Nearest to grand: indicator, reconquista, lyons, prize, offshore, guys, laser, multidimensional,
# Nearest to ocean: protease, agrarianism, sicilies, concerts, lifeless, duke, risked, herrn,
# Nearest to centre: herbst, zealots, pretending, monro, caricom, proportional, grandparent, convert,
# Nearest to san: quotient, nd, galliard, hz, unrecognized, iannis, mobilization, crawl,
# Nearest to something: stadium, committed, bystanders, cosmology, authorization, ili, revisionist, regarding,
# Nearest to construction: pack, iggy, automobile, shortcuts, litre, commerce, invictus, palazzo,
# Nearest to active: anger, decreased, historiae, continuously, democratic, worshipping, throughout, confluence,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7843 0.2490 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7590 0.2501 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7280 0.2520 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7091 0.2521 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7173 0.2492 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6819 0.2529 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7006 0.2559 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7424 0.2451 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6786 0.2430 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6696 0.2577 sec/batch
# Nearest to were: views, kanembu, stripped, fouling, clerk, confirm, franck, travelers,
# Nearest to on: plus, upland, dispenses, paisiello, attire, overlooked, mv, preparedness,
# Nearest to not: masked, captivity, subjugated, expel, quits, statism, resisting, situating,
# Nearest to up: custody, sparrowhawk, dalek, agility, dire, ninety, regents, acp,
# Nearest to the: succession, legacies, suomen, certificates, halting, automobile, somebody, divinity,
# Nearest to world: babes, older, decorate, incomes, theme, hernando, celebration, bought,
# Nearest to which: dominates, falling, avid, appoint, conclusions, limp, saaremaa, farming,
# Nearest to eight: seven, outgoing, crosby, nine, diamonds, bohlen, three, mitten,
# Nearest to report: wherever, transistors, outings, mithras, surinam, polk, intact, shipbuilding,
# Nearest to grand: reconquista, indicator, lyons, prize, roca, guys, seimas, falla,
# Nearest to ocean: protease, agrarianism, concerts, lifeless, sicilies, chickens, duke, pacific,
# Nearest to centre: herbst, caricom, zealots, pretending, monro, manasses, grandparent, weights,
# Nearest to san: nd, quotient, crawl, galliard, eidos, unrecognized, asf, mobilization,
# Nearest to something: stadium, committed, bystanders, cosmology, kamikaze, ili, authorization, storehouse,
# Nearest to construction: pack, automobile, iggy, litre, shortcuts, commerce, palazzo, invictus,
# Nearest to active: anger, decreased, historiae, ihre, continuously, worshipping, democratic, ophelia,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6591 0.2529 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6764 0.2527 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6225 0.2429 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6134 0.2451 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6149 0.2584 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6604 0.2607 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5989 0.1901 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5278 0.2457 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4944 0.2533 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4980 0.2554 sec/batch
# Nearest to were: views, stripped, kanembu, confirm, fouling, travelers, clerk, franck,
# Nearest to on: plus, dispenses, upland, preparedness, paisiello, attire, mq, inventors,
# Nearest to not: masked, subjugated, captivity, perishable, converse, statism, expel, quits,
# Nearest to up: dalek, custody, redefining, sparrowhawk, aye, agility, dire, ninety,
# Nearest to the: succession, halting, suomen, certificates, yam, legacies, legalization, kl,
# Nearest to world: incomes, hernando, decorate, britannicus, babes, older, ransom, amateur,
# Nearest to which: dominates, falling, radiohead, farming, conclusions, limp, machismo, saaremaa,
# Nearest to eight: seven, crosby, outgoing, nine, georg, bohlen, three, peter,
# Nearest to report: mithras, wherever, outings, transistors, surinam, polk, intact, prospered,
# Nearest to grand: reconquista, lyons, prize, indicator, roca, falla, guys, annibale,
# Nearest to ocean: protease, rivers, agrarianism, pacific, lifeless, chickens, sicilies, cooler,
# Nearest to centre: herbst, caricom, monro, zealots, mathew, pretending, grandparent, weights,
# Nearest to san: nd, quotient, eidos, asf, crawl, galliard, unrecognized, mobilization,
# Nearest to something: stadium, cosmology, committed, kamikaze, storehouse, asb, authorization, ili,
# Nearest to construction: pack, automobile, commerce, palazzo, litre, grants, borrowing, iggy,
# Nearest to active: anger, decreased, ihre, poppy, democratic, continuously, historiae, throughout,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4933 0.2613 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5032 0.2514 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4592 0.2622 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5111 0.2443 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5122 0.2449 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4792 0.2476 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4740 0.2506 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4397 0.2384 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4298 0.2385 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4366 0.2381 sec/batch
# Nearest to were: fouling, views, kanembu, stripped, confirm, travelers, marduk, offerings,
# Nearest to on: plus, dispenses, cancerous, upland, attire, mq, medic, lampooned,
# Nearest to not: converse, cannot, subjugated, perishable, captivity, masked, expel, absolutely,
# Nearest to up: dalek, redefining, sparrowhawk, custody, aye, agility, syringes, ninety,
# Nearest to the: halting, succession, legacies, kl, suomen, yam, taipei, certificates,
# Nearest to world: britannicus, hernando, decorate, ransom, incomes, amateur, kahului, pennants,
# Nearest to which: dominates, falling, radiohead, farming, materiel, conclusions, boomer, ribose,
# Nearest to eight: crosby, outgoing, bohlen, diamonds, mitten, vacuous, seven, glitch,
# Nearest to report: mithras, outings, wherever, surinam, transistors, cowdery, intact, prospered,
# Nearest to grand: reconquista, lyons, prize, roca, indicator, paternal, falla, annibale,
# Nearest to ocean: rivers, pacific, protease, coast, cooler, agrarianism, lifeless, chickens,
# Nearest to centre: herbst, caricom, monro, zealots, michigan, bionic, mathew, anegada,
# Nearest to san: nd, eidos, asf, crawl, vasquez, galliard, iannis, mobilization,
# Nearest to something: stadium, storehouse, kamikaze, cosmology, this, committed, authorization, bystanders,
# Nearest to construction: pack, commerce, automobile, grants, wallpapers, booming, shortcuts, favorable,
# Nearest to active: anger, decreased, ihre, poppy, democratic, continuously, malinche, ophelia,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4248 0.2513 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4165 0.2647 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4517 0.2523 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3972 0.2619 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4152 0.2464 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4353 0.2351 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3821 0.2359 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4073 0.2374 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4101 0.2385 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3584 0.2374 sec/batch
# Nearest to were: fouling, stripped, kanembu, travelers, views, marduk, offerings, continuing,
# Nearest to on: plus, medic, cancerous, galleon, passivity, upland, attire, frigates,
# Nearest to not: converse, cannot, masked, subjugated, absolutely, perishable, statism, captivity,
# Nearest to up: dalek, redefining, custody, pick, agility, sparrowhawk, torquay, bounced,
# Nearest to the: halting, succession, yam, suomen, legacies, kl, stunted, actium,
# Nearest to world: britannicus, hernando, decorate, incomes, ransom, amateur, babes, pennants,
# Nearest to which: falling, dominates, radiohead, heijenoort, conclusions, materiel, stroke, boomer,
# Nearest to eight: crosby, seven, three, outgoing, bohlen, six, diamonds, mitten,
# Nearest to report: mithras, outings, revolution, surinam, wherever, cowdery, external, transistors,
# Nearest to grand: reconquista, lyons, prize, roca, paternal, falla, indicator, nootka,
# Nearest to ocean: rivers, pacific, coast, cooler, sq, agrarianism, protease, volcanic,
# Nearest to centre: herbst, caricom, monro, zealots, michigan, fishermen, pretending, nightlife,
# Nearest to san: nd, eidos, asf, galliard, crawl, mobilization, tahiti, vasquez,
# Nearest to something: stadium, holiness, kamikaze, committed, distorts, asb, storehouse, bystanders,
# Nearest to construction: pack, commerce, automobile, wallpapers, litre, booming, iggy, borrowing,
# Nearest to active: anger, decreased, ihre, continuously, poppy, democratic, malinche, ophelia,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3872 0.2456 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3861 0.2665 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3660 0.2700 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3842 0.2579 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3912 0.2520 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.4099 0.2581 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4175 0.2539 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3649 0.2599 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3446 0.2627 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3229 0.2569 sec/batch
# Nearest to were: fouling, stripped, kanembu, travelers, offerings, continuing, royal, painted,
# Nearest to on: plus, mmol, medic, reproach, galleon, passivity, cancerous, frigates,
# Nearest to not: converse, cannot, likely, captivity, statism, arguments, absolutely, masked,
# Nearest to up: dalek, pick, custody, redefining, agility, cards, sparrowhawk, ninety,
# Nearest to the: succession, halting, legacies, actium, stunted, yam, suomen, barrels,
# Nearest to world: britannicus, hernando, incomes, amateur, decorate, pennants, subjected, silverdome,
# Nearest to which: dominates, falling, farming, materiel, boomer, radiohead, daggers, widest,
# Nearest to eight: three, crosby, seven, six, diamonds, bohlen, valentino, glitch,
# Nearest to report: outings, surinam, external, revolution, mithras, intact, cowdery, transistors,
# Nearest to grand: reconquista, lyons, roca, prize, falla, nootka, indicator, paternal,
# Nearest to ocean: pacific, rivers, cooler, protease, agrarianism, sq, coast, antarctic,
# Nearest to centre: herbst, caricom, fishermen, zealots, monro, michigan, bionic, pretending,
# Nearest to san: nd, eidos, asf, mobilization, galliard, crawl, tahiti, vasquez,
# Nearest to something: stadium, holiness, committed, kamikaze, asb, chemotherapy, bystanders, distorts,
# Nearest to construction: pack, automobile, commerce, booming, wallpapers, litre, shortcuts, vien,
# Nearest to active: anger, decreased, ihre, malinche, continuously, poppy, democratic, scientific,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3411 0.2805 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3206 0.2729 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3766 0.2606 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3730 0.2643 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3946 0.2691 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2772 0.2535 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3179 0.2519 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3215 0.2499 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2239 0.2360 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2965 0.2359 sec/batch
# Nearest to were: fouling, stripped, kanembu, travelers, continuing, planned, painted, reorganization,
# Nearest to on: plus, medic, mq, mmol, reproach, galleon, and, frigates,
# Nearest to not: converse, cannot, statism, likely, relativism, arguments, fully, absolutely,
# Nearest to up: dalek, pick, custody, agility, ninety, cards, redefining, aye,
# Nearest to the: succession, halting, margrethe, legacies, bonny, maharal, immigrate, stunted,
# Nearest to world: britannicus, hernando, celebration, amateur, silverdome, prized, daoism, subjected,
# Nearest to which: falling, dominates, machismo, farming, boomer, hypothalamus, stroke, radiohead,
# Nearest to eight: seven, three, six, crosby, bohlen, nine, valentino, diamonds,
# Nearest to report: external, revolution, surinam, mithras, outings, intact, polk, accessed,
# Nearest to grand: reconquista, lyons, roca, falla, nootka, prize, seimas, devolved,
# Nearest to ocean: pacific, rivers, cooler, antarctic, coast, volcanic, atlantic, harbors,
# Nearest to centre: herbst, caricom, michigan, nightlife, visitors, bionic, fishermen, monro,
# Nearest to san: nd, asf, eidos, vasquez, mobilization, galliard, crawl, county,
# Nearest to something: kamikaze, stadium, holiness, chemotherapy, asb, committed, authorization, distorts,
# Nearest to construction: automobile, pack, commerce, booming, litre, wallpapers, shortcuts, vien,
# Nearest to active: anger, decreased, ihre, democratic, malinche, scientific, poppy, continuously,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3023 0.2391 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3119 0.2346 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3443 0.1179 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2176 0.2364 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2270 0.2401 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2238 0.2490 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2272 0.2628 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2273 0.2638 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2349 0.2530 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2059 0.2606 sec/batch
# Nearest to were: fouling, stripped, kanembu, travelers, assault, painted, planned, offerings,
# Nearest to on: plus, medic, mmol, mq, frigates, out, galleon, schematics,
# Nearest to not: converse, absolutely, cannot, likely, statism, resisting, kilotons, arguments,
# Nearest to up: pick, dalek, agility, custody, aye, redefining, sparrowhawk, dire,
# Nearest to the: immigrate, halting, succession, suomen, margrethe, barrels, bonny, oceania,
# Nearest to world: britannicus, hernando, daoism, amateur, celebration, ransom, populous, pennants,
# Nearest to which: dominates, falling, machismo, farming, materiel, daggers, whole, venetia,
# Nearest to eight: seven, three, six, bohlen, crosby, diamonds, nine, valentino,
# Nearest to report: external, revolution, accessed, surinam, outings, links, mithras, polk,
# Nearest to grand: reconquista, lyons, roca, falla, nootka, kenji, egan, ascari,
# Nearest to ocean: pacific, rivers, antarctic, sq, atlantic, cooler, harbors, coast,
# Nearest to centre: caricom, herbst, nightlife, visitors, michigan, bionic, fishermen, dits,
# Nearest to san: nd, asf, corridor, vasquez, county, eidos, chain, galliard,
# Nearest to something: kamikaze, chemotherapy, committed, holiness, stadium, asb, tambourine, distorts,
# Nearest to construction: automobile, commerce, pack, booming, wallpapers, mychal, centre, litre,
# Nearest to active: decreased, ihre, anger, democratic, poppy, continuously, malinche, gulden,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2436 0.2595 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2216 0.2500 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2050 0.2481 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1480 0.2369 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1832 0.2355 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1634 0.2346 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1728 0.2328 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1843 0.2357 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2153 0.2361 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1789 0.2302 sec/batch
# Nearest to were: fouling, stripped, travelers, kanembu, painted, jutting, assault, marduk,
# Nearest to on: plus, overwritten, frigates, and, medic, mmol, mq, vociferous,
# Nearest to not: converse, cannot, absolutely, statism, resisting, relativism, kilotons, likely,
# Nearest to up: pick, agility, custody, dalek, cards, redefining, aye, dire,
# Nearest to the: halting, immigrate, stunted, margrethe, bonny, innings, plasmodium, provable,
# Nearest to world: britannicus, daoism, prized, pennants, amateur, graced, populous, related,
# Nearest to which: falling, dominates, stroke, hypothalamus, the, whole, farming, heijenoort,
# Nearest to eight: seven, six, three, bohlen, valentino, crosby, nine, bedford,
# Nearest to report: external, accessed, revolution, links, surinam, outings, cowdery, january,
# Nearest to grand: reconquista, lyons, roca, falla, kenji, indicator, nootka, ascari,
# Nearest to ocean: pacific, rivers, antarctic, volcanic, sq, cooler, atlantic, harbors,
# Nearest to centre: caricom, herbst, visitors, nightlife, dits, michigan, construction, bionic,
# Nearest to san: nd, corridor, asf, vasquez, eidos, iannis, galliard, county,
# Nearest to something: kamikaze, chemotherapy, stadium, holiness, asb, tambourine, committed, storehouse,
# Nearest to construction: automobile, commerce, booming, pack, wallpapers, mychal, centre, seif,
# Nearest to active: decreased, ihre, anger, democratic, continuously, malinche, poppy, scientific,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1795 0.2392 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2364 0.2473 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1779 0.2507 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1750 0.2402 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1918 0.2624 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1856 0.2698 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1883 0.2634 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1661 0.2749 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1702 0.2569 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1558 0.2523 sec/batch
# Nearest to were: stripped, fouling, kanembu, painted, travelers, planned, reorganization, assault,
# Nearest to on: plus, vociferous, and, galleon, diplomatique, mq, frigates, reproach,
# Nearest to not: converse, absolutely, statism, cannot, kilotons, hospice, relativism, waqf,
# Nearest to up: pick, agility, dalek, aye, custody, redefining, cards, ninety,
# Nearest to the: immigrate, stunted, bonny, halting, succession, actium, legacies, margrethe,
# Nearest to world: britannicus, pennants, amateur, libra, silverdome, graced, daoism, celebration,
# Nearest to which: falling, dominates, the, boomer, dominoes, stroke, heijenoort, whole,
# Nearest to eight: seven, six, three, nine, five, bohlen, valentino, two,
# Nearest to report: external, accessed, links, revolution, archives, embedded, january, adhd,
# Nearest to grand: reconquista, lyons, roca, indicator, falla, ascari, semiautomatic, kenji,
# Nearest to ocean: pacific, rivers, antarctic, sq, atlantic, volcanic, alumina, agrarianism,
# Nearest to centre: caricom, herbst, visitors, nightlife, dits, fishermen, construction, bionic,
# Nearest to san: nd, asf, iannis, eidos, lewisham, corridor, crawl, chain,
# Nearest to something: stadium, kamikaze, chemotherapy, holiness, asb, committed, tambourine, contempt,
# Nearest to construction: automobile, commerce, booming, pack, wallpapers, palazzo, centre, litre,
# Nearest to active: decreased, ihre, anger, continuously, malinche, poppy, democratic, scientific,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1870 0.2632 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1604 0.2443 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1615 0.2407 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1856 0.2534 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1417 0.2505 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1632 0.2460 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1624 0.2415 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1067 0.2470 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1856 0.2491 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1766 0.2551 sec/batch
# Nearest to were: stripped, fouling, kanembu, travelers, painted, planned, assault, pursuance,
# Nearest to on: plus, and, diplomatique, vociferous, medic, reproach, mq, galleon,
# Nearest to not: converse, statism, absolutely, waqf, relativism, hospice, likely, kilotons,
# Nearest to up: pick, dalek, agility, custody, redefining, ninety, aye, cards,
# Nearest to the: bonny, immigrate, succession, which, actium, in, of, institution,
# Nearest to world: britannicus, graced, libra, amateur, pennants, pietist, celebration, albigenses,
# Nearest to which: falling, the, daggers, dominates, boomer, venetia, cameroun, farming,
# Nearest to eight: seven, six, three, five, nine, two, one, valentino,
# Nearest to report: external, links, accessed, january, archives, amnesty, revolution, integration,
# Nearest to grand: reconquista, lyons, falla, roca, ascari, poll, kenji, indicator,
# Nearest to ocean: pacific, antarctic, rivers, atlantic, alumina, satellite, agrarianism, coast,
# Nearest to centre: caricom, herbst, visitors, nightlife, dits, construction, bionic, fishermen,
# Nearest to san: nd, asf, eidos, iannis, crawl, chain, lewisham, galliard,
# Nearest to something: kamikaze, chemotherapy, stadium, committed, holiness, burlesque, asb, tambourine,
# Nearest to construction: automobile, commerce, booming, pack, centre, palazzo, wallpapers, przewodnicz,
# Nearest to active: decreased, ihre, anger, malinche, democratic, continuously, zambian, scientific,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2416 0.2597 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1498 0.2580 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1309 0.2511 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1414 0.2529 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0250 0.2598 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1331 0.2687 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1591 0.2641 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1395 0.2682 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1594 0.0660 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1037 0.2723 sec/batch
# Nearest to were: stripped, fouling, travelers, painted, planned, pursuance, kanembu, assault,
# Nearest to on: plus, and, medic, galleon, vociferous, overwritten, to, wozniak,
# Nearest to not: converse, yunnan, absolutely, waqf, fully, squaresoft, hospice, kilotons,
# Nearest to up: pick, agility, dalek, aye, cards, ninety, redefining, custody,
# Nearest to the: immigrate, stunted, bonny, in, which, a, of, valdez,
# Nearest to world: britannicus, libra, graced, pietist, prized, populous, daoism, amateur,
# Nearest to which: falling, the, a, dominates, rnb, boomer, hypothalamus, venetia,
# Nearest to eight: three, seven, six, nine, five, two, zero, valentino,
# Nearest to report: external, accessed, links, archives, january, adhd, reports, amnesty,
# Nearest to grand: reconquista, lyons, roca, ascari, falla, kenji, kawasaki, indicator,
# Nearest to ocean: pacific, antarctic, satellite, atlantic, rivers, alumina, coast, agrarianism,
# Nearest to centre: visitors, caricom, herbst, nightlife, construction, dits, bionic, urban,
# Nearest to san: nd, asf, eidos, iannis, crawl, lewisham, chain, begins,
# Nearest to something: kamikaze, stadium, chemotherapy, committed, burlesque, tambourine, contempt, asb,
# Nearest to construction: automobile, commerce, booming, wallpapers, centre, palazzo, pack, mychal,
# Nearest to active: decreased, ihre, anger, democratic, continuously, malinche, zambian, scientific,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0500 0.2734 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0854 0.2739 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1058 0.2664 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0637 0.2745 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0932 0.2710 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0328 0.2657 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1120 0.2588 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0989 0.2620 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1030 0.2638 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0289 0.2793 sec/batch
# Nearest to were: stripped, fouling, kanembu, travelers, marduk, sailed, planned, pursuance,
# Nearest to on: plus, overwritten, and, medic, wozniak, deadline, galleon, spacecraft,
# Nearest to not: converse, absolutely, yunnan, kilotons, cannot, hospice, waqf, likely,
# Nearest to up: pick, aye, agility, cards, dalek, ninety, redefining, paralysis,
# Nearest to the: immigrate, which, in, oceania, of, is, repopulated, stunted,
# Nearest to world: graced, pennants, populous, albigenses, related, libra, britannicus, daoism,
# Nearest to which: the, falling, dominates, a, daggers, venetia, tj, farming,
# Nearest to eight: seven, three, six, five, nine, valentino, two, zero,
# Nearest to report: external, accessed, links, january, amnesty, adhd, archives, surinam,
# Nearest to grand: reconquista, ascari, lyons, roca, falla, indicator, dorset, kenji,
# Nearest to ocean: pacific, antarctic, volcanic, atlantic, satellite, coast, coaxial, alumina,
# Nearest to centre: visitors, caricom, nightlife, herbst, dits, construction, tent, provincias,
# Nearest to san: nd, asf, eidos, iannis, chain, crawl, lewisham, vasquez,
# Nearest to something: kamikaze, stadium, chemotherapy, burlesque, tambourine, globus, committed, asb,
# Nearest to construction: automobile, commerce, booming, wallpapers, palazzo, mychal, centre, przewodnicz,
# Nearest to active: decreased, ihre, continuously, anger, gulden, malinche, dissociate, democratic,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0303 0.2781 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0316 0.2577 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0327 0.2447 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0711 0.2459 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0577 0.2448 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0409 0.2521 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0628 0.2533 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0846 0.2539 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0444 0.2515 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0691 0.2555 sec/batch
# Nearest to were: stripped, fouling, kanembu, travelers, ww, planned, painted, mainframe,
# Nearest to on: plus, and, vociferous, overwritten, wozniak, diplomatique, deadline, galleon,
# Nearest to not: converse, absolutely, yunnan, wished, altizer, kilotons, cannot, statism,
# Nearest to up: pick, agility, aye, cards, dalek, redefining, rails, decreasing,
# Nearest to the: of, is, which, a, in, immigrate, an, it,
# Nearest to world: pennants, libra, graced, daoism, pietist, related, amateur, britannicus,
# Nearest to which: the, a, falling, dominates, might, daggers, dominoes, venetia,
# Nearest to eight: six, seven, three, nine, five, two, valentino, one,
# Nearest to report: external, accessed, links, adhd, reports, amnesty, january, archives,
# Nearest to grand: reconquista, roca, ascari, falla, indicator, lyons, kenji, pml,
# Nearest to ocean: pacific, antarctic, volcanic, atlantic, coast, alumina, rivers, agrarianism,
# Nearest to centre: visitors, caricom, nightlife, dits, pretending, tent, construction, herbst,
# Nearest to san: eidos, asf, nd, iannis, lewisham, chain, acosta, ramirez,
# Nearest to something: kamikaze, chemotherapy, stadium, burlesque, asb, committed, holiness, distorts,
# Nearest to construction: automobile, commerce, booming, wallpapers, palazzo, centre, seif, finite,
# Nearest to active: decreased, ihre, anger, continuously, malinche, dissociate, poppy, zambian,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0753 0.2569 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0632 0.2521 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0954 0.2492 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0292 0.2545 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0797 0.2507 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0523 0.2494 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0722 0.2593 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0416 0.2637 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0665 0.2621 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0718 0.2624 sec/batch
# Nearest to were: stripped, kanembu, fouling, travelers, planned, marduk, pursuance, tribes,
# Nearest to on: plus, and, vociferous, diplomatique, overwritten, wozniak, galleon, gorski,
# Nearest to not: converse, absolutely, altizer, wished, waqf, yunnan, statism, cannot,
# Nearest to up: aye, pick, agility, dalek, cards, paralysis, rails, ninety,
# Nearest to the: of, which, in, immigrate, actium, succession, a, to,
# Nearest to world: pennants, daoism, britannicus, albigenses, pietist, graced, libra, vauxhall,
# Nearest to which: the, falling, a, itself, venetia, daggers, dominoes, dominates,
# Nearest to eight: three, six, seven, five, nine, two, valentino, zero,
# Nearest to report: external, reports, links, accessed, amnesty, january, archives, adhd,
# Nearest to grand: reconquista, roca, ascari, indicator, falla, lyons, kenji, pml,
# Nearest to ocean: pacific, atlantic, antarctic, alumina, coaxial, volcanic, agrarianism, griggs,
# Nearest to centre: visitors, nightlife, caricom, tent, dits, herbst, construction, provincias,
# Nearest to san: asf, eidos, iannis, nd, acosta, ramirez, lewisham, chain,
# Nearest to something: kamikaze, chemotherapy, stadium, burlesque, holiness, committed, asb, globus,
# Nearest to construction: automobile, commerce, booming, seif, palazzo, wallpapers, finite, centre,
# Nearest to active: decreased, ihre, anger, continuously, dissociate, monitoring, zambian, malinche,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0733 0.2669 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0179 0.2662 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0573 0.2651 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0760 0.2759 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1040 0.2659 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1176 0.2637 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1388 0.2642 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0525 0.3215 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0258 0.3088 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0455 0.2872 sec/batch
# Nearest to were: stripped, travelers, planned, kanembu, fouling, pursuance, ww, mainframe,
# Nearest to on: plus, and, overwritten, vociferous, medic, deadline, to, glacial,
# Nearest to not: converse, absolutely, wished, altizer, waqf, statism, cannot, yunnan,
# Nearest to up: pick, aye, rails, agility, ninety, paralysis, dalek, redefining,
# Nearest to the: of, in, which, a, is, to, institution, maharal,
# Nearest to world: daoism, amateur, pietist, celebration, libra, pennants, graced, related,
# Nearest to which: the, a, falling, itself, venetia, daggers, dominates, dominoes,
# Nearest to eight: three, six, seven, five, nine, two, one, valentino,
# Nearest to report: external, reports, adhd, amnesty, accessed, links, january, archives,
# Nearest to grand: reconquista, ascari, roca, falla, pml, lyons, curbed, awami,
# Nearest to ocean: pacific, atlantic, coaxial, antarctic, griggs, coast, agrarianism, alumina,
# Nearest to centre: visitors, nightlife, tent, caricom, dits, construction, herbst, provincias,
# Nearest to san: eidos, asf, iannis, acosta, chain, ramirez, crawl, lewisham,
# Nearest to something: kamikaze, chemotherapy, stadium, burlesque, committed, tambourine, asb, fugal,
# Nearest to construction: automobile, commerce, booming, wallpapers, seif, palazzo, przewodnicz, centre,
# Nearest to active: decreased, ihre, anger, continuously, malinche, zambian, ophelia, democratic,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9726 0.2654 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0318 0.2632 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0326 0.2635 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0414 0.2626 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0374 0.2644 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0464 0.2812 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9806 0.2652 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9988 0.2635 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0319 0.2635 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9956 0.2633 sec/batch
# Nearest to were: stripped, fouling, travelers, pursuance, planned, kanembu, staggering, marduk,
# Nearest to on: plus, and, overwritten, spacecraft, to, medic, undisturbed, mmol,
# Nearest to not: converse, altizer, yunnan, wished, absolutely, kilotons, waqf, hypergiant,
# Nearest to up: aye, pick, redefining, ninety, rails, agility, paralysis, dalek,
# Nearest to the: of, in, a, which, is, to, maggiore, an,
# Nearest to world: daoism, libra, pennants, pietist, amateur, britannicus, graced, during,
# Nearest to which: the, a, itself, falling, venetia, dominates, its, regent,
# Nearest to eight: three, six, seven, nine, five, one, two, zero,
# Nearest to report: external, reports, adhd, accessed, links, amnesty, january, inspirations,
# Nearest to grand: reconquista, ascari, roca, lyons, falla, prix, kenji, pml,
# Nearest to ocean: pacific, atlantic, coaxial, alumina, oceans, antarctic, griggs, intersputnik,
# Nearest to centre: visitors, nightlife, tent, construction, dits, caricom, domes, provincias,
# Nearest to san: asf, eidos, iannis, chain, vasquez, ramirez, merger, crawl,
# Nearest to something: kamikaze, chemotherapy, burlesque, stadium, committed, fugal, tambourine, asb,
# Nearest to construction: automobile, centre, przewodnicz, commerce, mychal, seif, wallpapers, palazzo,
# Nearest to active: decreased, ihre, anger, continuously, dissociate, poppy, malinche, milligrams,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9763 0.2675 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9705 0.2620 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0242 0.2625 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0235 0.2633 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0175 0.2615 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9606 0.2736 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9240 0.2496 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9585 0.2401 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9239 0.2354 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9635 0.2356 sec/batch
# Nearest to were: stripped, travelers, fouling, kanembu, pursuance, marduk, planned, ww,
# Nearest to on: plus, and, overwritten, deadline, to, pickups, of, wozniak,
# Nearest to not: converse, yunnan, altizer, absolutely, wished, syllabaries, hypergiant, kilotons,
# Nearest to up: pick, aye, cards, ninety, rails, back, agility, proud,
# Nearest to the: a, of, in, which, to, is, an, it,
# Nearest to world: populous, pennants, amateur, daoism, graced, libra, vauxhall, silverdome,
# Nearest to which: the, a, itself, dominates, widest, falling, its, daggers,
# Nearest to eight: six, three, seven, five, nine, two, one, zero,
# Nearest to report: external, reports, adhd, links, accessed, archives, january, amnesty,
# Nearest to grand: reconquista, ascari, roca, pml, falla, indicator, kenji, prix,
# Nearest to ocean: pacific, coaxial, atlantic, alumina, antarctic, occupies, oceans, intersputnik,
# Nearest to centre: visitors, nightlife, tent, dits, construction, caricom, provincias, pretending,
# Nearest to san: francisco, asf, eidos, lewisham, california, iannis, merger, ramirez,
# Nearest to something: chemotherapy, burlesque, stadium, kamikaze, fugal, tambourine, asb, holiness,
# Nearest to construction: automobile, booming, commerce, przewodnicz, mychal, wallpapers, centre, seif,
# Nearest to active: decreased, ihre, dissociate, continuously, milligrams, poppy, monitoring, anger,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9906 0.2409 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9961 0.2343 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9908 0.2367 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9987 0.2356 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0503 0.2357 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9476 0.2453 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9920 0.2436 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0062 0.2441 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9782 0.2608 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9701 0.2582 sec/batch
# Nearest to were: stripped, travelers, kanembu, fouling, mainframe, planned, staggering, pursuance,
# Nearest to on: plus, and, wozniak, overwritten, this, of, vociferous, to,
# Nearest to not: converse, altizer, wished, squaresoft, absolutely, differentiable, cannot, yunnan,
# Nearest to up: pick, aye, cards, proud, rails, agility, ninety, dalek,
# Nearest to the: of, a, in, which, is, to, an, same,
# Nearest to world: pennants, amateur, celebrating, docklands, graced, apron, daoism, libra,
# Nearest to which: the, a, itself, venetia, in, falling, same, dominoes,
# Nearest to eight: six, seven, three, five, one, nine, two, zero,
# Nearest to report: external, reports, adhd, links, accessed, archives, amnesty, summary,
# Nearest to grand: reconquista, ascari, prix, roca, pml, falla, lyons, dreamland,
# Nearest to ocean: pacific, atlantic, fm, coaxial, adirondack, oceans, intersputnik, antarctic,
# Nearest to centre: visitors, tent, nightlife, provincias, dits, pretending, caricom, donegal,
# Nearest to san: eidos, asf, francisco, ramirez, iannis, vasquez, merger, tert,
# Nearest to something: burlesque, stadium, chemotherapy, kamikaze, fugal, tambourine, holiness, reasonableness,
# Nearest to construction: automobile, przewodnicz, wallpapers, mychal, booming, commerce, finite, quays,
# Nearest to active: decreased, ihre, continuously, anger, dissociate, poppy, milligrams, monitoring,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0063 0.2535 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9883 0.2585 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9964 0.2655 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9956 0.2634 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0393 0.2675 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9998 0.2600 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0037 0.2732 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9828 0.2681 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9838 0.2583 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0298 0.2670 sec/batch
# Nearest to were: stripped, kanembu, ww, mainframe, travelers, planned, staggering, fouling,
# Nearest to on: and, plus, of, to, this, overwritten, wozniak, vociferous,
# Nearest to not: converse, altizer, yunnan, syllabaries, hypergiant, sherborne, illiberal, wished,
# Nearest to up: aye, pick, ninety, cards, rails, proud, torquay, agility,
# Nearest to the: of, in, which, a, to, is, and, an,
# Nearest to world: amateur, daoism, pennants, pietist, during, celebration, docklands, celebrating,
# Nearest to which: the, a, itself, its, in, dominates, venetia, same,
# Nearest to eight: six, three, seven, five, nine, one, two, zero,
# Nearest to report: external, reports, links, adhd, summary, accessed, archives, amnesty,
# Nearest to grand: reconquista, ascari, prix, falla, roca, pml, dreamland, curbed,
# Nearest to ocean: pacific, atlantic, intersputnik, coaxial, fm, tele, shortwave, antarctic,
# Nearest to centre: visitors, tent, nightlife, provincias, dits, construction, donegal, caricom,
# Nearest to san: eidos, asf, iannis, francisco, tert, ramirez, chain, merger,
# Nearest to something: burlesque, chemotherapy, kamikaze, stadium, fugal, globus, focussing, tambourine,
# Nearest to construction: automobile, przewodnicz, booming, mychal, seif, commerce, centre, wallpapers,
# Nearest to active: decreased, ihre, anger, continuously, dissociate, malinche, zambian, milligrams,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9701 0.2754 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0776 0.2659 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0756 0.2550 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0628 0.2558 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9290 0.2558 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9539 0.2552 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9373 0.2561 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9331 0.2576 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9840 0.2553 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9726 0.2561 sec/batch
# ...
# Nearest to active: ihre, decreased, passive, milligrams, monitoring, dissociate, es, nanotube,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8600 0.2396 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7838 0.2351 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8303 0.2343 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7736 0.2349 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8534 0.2331 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8863 0.2344 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8353 0.2343 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8337 0.2352 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8699 0.2343 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8910 0.2356 sec/batch
# Nearest to were: was, earlier, by, and, could, had, for, would,
# Nearest to on: the, of, this, and, in, to, for, july,
# Nearest to not: but, would, because, did, this, that, to, altizer,
# Nearest to up: to, and, pick, internalism, aye, proud, three, a,
# Nearest to the: of, a, in, and, is, as, which, to,
# Nearest to world: apron, immersive, hosted, nine, elia, imd, during, cia,
# Nearest to which: the, a, itself, of, in, its, as, by,
# Nearest to eight: six, one, three, nine, seven, five, two, zero,
# Nearest to report: reports, summary, adhd, embedded, inspirations, archives, greenfacts, sympathizer,
# Nearest to grand: reconquista, prix, ascari, kawasaki, racing, etude, mutagen, moderns,
# Nearest to ocean: pacific, intersputnik, atlantic, daoxuan, oceans, alumina, occupies, shortwave,
# Nearest to centre: tent, anamorphosis, provincias, berkshire, donegal, dits, visitors, onizuka,
# Nearest to san: francisco, california, diego, tert, eidos, domingo, jose, adour,
# Nearest to something: burlesque, chemotherapy, webpages, fugal, fancher, swinging, denial, focussing,
# Nearest to construction: booming, quarry, seif, monorails, planetarium, wallpapers, bloemfontein, przewodnicz,
# Nearest to active: decreased, ihre, milligrams, passive, monitoring, es, dissociate, celt,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8253 0.2393 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8534 0.2351 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8382 0.2343 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8667 0.2349 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8941 0.2338 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8695 0.2364 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8578 0.2346 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8402 0.2348 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8843 0.2360 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8672 0.2355 sec/batch
# Nearest to were: was, and, earlier, had, by, later, could, speculated,
# Nearest to on: the, of, and, this, in, to, a, for,
# Nearest to not: but, would, did, because, to, that, this, nevertheless,
# Nearest to up: and, internalism, pick, aye, three, proud, to, ahimelech,
# Nearest to the: of, in, a, and, which, to, s, on,
# Nearest to world: nine, apron, immersive, imd, elia, during, outbreak, cia,
# Nearest to which: the, a, itself, of, in, as, by, its,
# Nearest to eight: three, six, nine, five, one, seven, two, four,
# Nearest to report: reports, summary, adhd, embedded, manat, greenfacts, ipcc, archives,
# Nearest to grand: reconquista, prix, ascari, moderns, racing, mutagen, drivers, kawasaki,
# Nearest to ocean: pacific, intersputnik, atlantic, daoxuan, occupies, alumina, oceans, shortwave,
# Nearest to centre: tent, provincias, anamorphosis, donegal, dits, berkshire, weights, visitors,
# Nearest to san: francisco, california, diego, tert, eidos, domingo, jose, adour,
# Nearest to something: chemotherapy, burlesque, webpages, fancher, denial, focussing, swinging, fugal,
# Nearest to construction: quarry, booming, planetarium, bloemfontein, monorails, seif, przewodnicz, wallpapers,
# Nearest to active: ihre, passive, decreased, milligrams, es, celt, dissociate, indicative,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8609 0.2389 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8377 0.2336 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8037 0.2355 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8167 0.2329 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9319 0.2361 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8260 0.2357 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9612 0.2365 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9207 0.2402 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8946 0.2348 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8171 0.2335 sec/batch
# Nearest to were: was, and, earlier, by, had, could, later, as,
# Nearest to on: the, of, and, in, this, for, to, also,
# Nearest to not: but, because, did, would, that, to, this, billion,
# Nearest to up: and, pick, internalism, proud, aye, of, three, a,
# Nearest to the: of, a, in, and, on, which, as, is,
# Nearest to world: nine, apron, immersive, imd, hosted, elia, outbreak, during,
# Nearest to which: the, a, itself, of, and, in, as, by,
# Nearest to eight: six, three, five, one, seven, nine, two, four,
# Nearest to report: reports, summary, adhd, ipcc, embedded, sympathizer, manat, oic,
# Nearest to grand: reconquista, prix, ascari, moderns, etude, racing, kawasaki, jurisdictions,
# Nearest to ocean: pacific, intersputnik, atlantic, occupies, daoxuan, alumina, shortwave, vindhya,
# Nearest to centre: tent, provincias, anamorphosis, dits, donegal, visitors, berkshire, london,
# Nearest to san: francisco, california, diego, tert, eidos, domingo, jose, adour,
# Nearest to something: chemotherapy, burlesque, fancher, denial, swinging, webpages, you, sculpted,
# Nearest to construction: booming, quarry, monorails, planetarium, seif, bloemfontein, incursion, przewodnicz,
# Nearest to active: ihre, passive, decreased, celt, es, indicative, milligrams, l,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8338 0.2369 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8683 0.2353 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8286 0.2350 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8735 0.2359 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8488 0.2355 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8595 0.2354 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8467 0.1761 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8491 0.2364 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8266 0.2354 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8581 0.2358 sec/batch
# Nearest to were: was, and, had, earlier, could, by, speculated, would,
# Nearest to on: the, of, and, in, this, to, for, a,
# Nearest to not: but, because, would, to, that, did, in, this,
# Nearest to up: and, to, pick, chopsticks, their, internalism, aye, proud,
# Nearest to the: of, a, in, and, which, to, is, on,
# Nearest to world: nine, immersive, apron, during, imd, elia, hosted, outbreak,
# Nearest to which: the, a, itself, of, and, its, is, in,
# Nearest to eight: six, one, nine, three, five, seven, two, zero,
# Nearest to report: reports, summary, adhd, embedded, greenfacts, ipcc, chronology, archives,
# Nearest to grand: reconquista, prix, ascari, racing, moderns, etude, drivers, kawasaki,
# Nearest to ocean: pacific, atlantic, intersputnik, occupies, daoxuan, alumina, vindhya, adagio,
# Nearest to centre: tent, provincias, anamorphosis, berkshire, dits, donegal, adjoining, visitors,
# Nearest to san: california, francisco, diego, tert, eidos, domingo, adour, jose,
# Nearest to something: chemotherapy, burlesque, webpages, swinging, denial, fancher, sculpted, niggers,
# Nearest to construction: booming, quarry, seif, planetarium, monorails, bloemfontein, incursion, przewodnicz,
# Nearest to active: ihre, passive, decreased, es, celt, monitoring, indicative, present,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8275 0.2404 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8376 0.2354 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7578 0.2341 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8745 0.2367 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8464 0.2343 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8598 0.2352 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8532 0.2349 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7413 0.2354 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8135 0.2345 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7816 0.2343 sec/batch
# Nearest to were: was, had, earlier, and, by, could, first, would,
# Nearest to on: the, of, in, and, this, to, for, a,
# Nearest to not: but, this, that, because, in, to, would, did,
# Nearest to up: and, to, their, internalism, in, pick, three, proud,
# Nearest to the: of, in, a, is, and, which, to, on,
# Nearest to world: nine, imd, apron, during, cia, immersive, hosted, elia,
# Nearest to which: a, the, itself, of, is, its, by, and,
# Nearest to eight: three, nine, six, five, one, seven, two, zero,
# Nearest to report: reports, summary, adhd, greenfacts, embedded, manat, ipcc, archives,
# Nearest to grand: reconquista, prix, ascari, moderns, etude, kawasaki, racing, jurisdictions,
# Nearest to ocean: pacific, atlantic, intersputnik, alumina, daoxuan, adagio, occupies, fm,
# Nearest to centre: tent, anamorphosis, provincias, dits, berkshire, donegal, mycology, kew,
# Nearest to san: california, francisco, diego, tert, eidos, jose, domingo, adour,
# Nearest to something: burlesque, chemotherapy, webpages, swinging, denial, fancher, flapping, babbling,
# Nearest to construction: booming, quarry, monorails, seif, planetarium, przewodnicz, bloemfontein, incursion,
# Nearest to active: passive, ihre, decreased, dissociate, monitoring, present, milligrams, es,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7759 0.2375 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8318 0.2351 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8910 0.2345 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8314 0.2348 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8356 0.2323 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8990 0.2355 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8057 0.2345 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8433 0.2351 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8600 0.2349 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8455 0.2351 sec/batch
# Nearest to were: was, earlier, by, had, and, could, only, would,
# Nearest to on: the, of, in, this, and, for, to, a,
# Nearest to not: but, this, because, in, would, that, to, did,
# Nearest to up: and, to, in, their, pick, of, proud, internalism,
# Nearest to the: of, in, a, which, is, and, on, an,
# Nearest to world: immersive, nine, imd, apron, elia, hosted, during, triumph,
# Nearest to which: the, a, of, itself, in, is, with, an,
# Nearest to eight: three, six, nine, one, five, seven, two, four,
# Nearest to report: reports, summary, adhd, embedded, greenfacts, ipcc, manat, inspirations,
# Nearest to grand: reconquista, prix, ascari, racing, moderns, kawasaki, drivers, etude,
# Nearest to ocean: pacific, atlantic, intersputnik, daoxuan, alumina, fm, adagio, vindhya,
# Nearest to centre: tent, anamorphosis, dits, provincias, berkshire, donegal, kew, onizuka,
# Nearest to san: francisco, california, diego, eidos, tert, domingo, jose, adour,
# Nearest to something: burlesque, chemotherapy, swinging, fancher, denial, webpages, flapping, fugal,
# Nearest to construction: booming, quarry, planetarium, monorails, seif, przewodnicz, wallpapers, bloemfontein,
# Nearest to active: passive, ihre, decreased, es, dissociate, monitoring, celt, milligrams,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8551 0.2363 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8502 0.2357 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8466 0.2362 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8470 0.2426 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8544 0.2400 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8393 0.2346 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8502 0.2350 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8363 0.2342 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8258 0.2342 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8074 0.2352 sec/batch
# Nearest to were: was, and, had, by, earlier, could, their, only,
# Nearest to on: the, of, in, for, and, this, to, a,
# Nearest to not: but, this, because, that, in, to, did, only,
# Nearest to up: and, their, to, of, in, a, pick, are,
# Nearest to the: of, in, a, and, which, on, to, is,
# Nearest to world: nine, imd, immersive, during, one, apron, elia, cia,
# Nearest to which: the, a, of, itself, and, with, in, by,
# Nearest to eight: three, six, five, one, two, nine, seven, zero,
# Nearest to report: reports, summary, greenfacts, ipcc, adhd, manat, embedded, archives,
# Nearest to grand: reconquista, prix, ascari, moderns, jurisdictions, etude, falla, hobby,
# Nearest to ocean: pacific, atlantic, intersputnik, daoxuan, adagio, fm, shortwave, intelsat,
# Nearest to centre: tent, anamorphosis, dits, donegal, berkshire, provincias, kew, london,
# Nearest to san: francisco, california, eidos, diego, tert, domingo, jose, adour,
# Nearest to something: chemotherapy, burlesque, webpages, denial, swinging, niggers, fancher, flapping,
# Nearest to construction: booming, quarry, planetarium, monorails, seif, przewodnicz, incursion, bloemfontein,
# Nearest to active: ihre, passive, decreased, indicative, dissociate, es, defences, celt,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8821 0.2400 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8273 0.2372 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9399 0.2348 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9004 0.2348 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9151 0.2333 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7871 0.2344 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7703 0.2346 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8714 0.2334 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7710 0.2359 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8609 0.2353 sec/batch
# Nearest to were: was, had, could, earlier, by, and, surfaced, only,
# Nearest to on: the, in, of, for, this, and, to, a,
# Nearest to not: but, this, because, did, to, in, would, that,
# Nearest to up: and, their, to, of, in, a, pick, as,
# Nearest to the: of, in, a, which, and, on, is, as,
# Nearest to world: nine, imd, elia, immersive, apron, hosted, united, triumph,
# Nearest to which: a, the, of, itself, as, is, in, with,
# Nearest to eight: six, one, nine, three, five, seven, two, zero,
# Nearest to report: reports, summary, greenfacts, adhd, ipcc, embedded, manat, bothnian,
# Nearest to grand: reconquista, prix, ascari, moderns, kawasaki, jurisdictions, etude, falla,
# Nearest to ocean: pacific, intersputnik, atlantic, daoxuan, fm, adagio, inmarsat, intelsat,
# Nearest to centre: tent, anamorphosis, donegal, provincias, dits, berkshire, visitors, kew,
# Nearest to san: francisco, california, diego, eidos, tert, domingo, adour, tampico,
# Nearest to something: webpages, chemotherapy, burlesque, denial, fancher, niggers, swinging, kamikaze,
# Nearest to construction: booming, planetarium, monorails, quarry, seif, incursion, bloemfontein, przewodnicz,
# Nearest to active: ihre, passive, es, present, indicative, decreased, nanotube, l,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8178 0.2380 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
